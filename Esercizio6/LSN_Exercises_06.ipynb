# %% [markdown]
# # <span style="color:blue">  Numerical exercises 6</span> Igor Vasiljevic 11191A

# %% [markdown]
# ## Here the results for 1D Ising Model with Metropolis algorithm and Gibbs sampling algorithm

# %% [markdown]
# ## Both Metropolis and Gibbs sampling algorithm are Markov Chain Monte Carlo method used for sample probability distribution (Ising Model); The Metropolos sampre from a target distribution by proposing with moves a new states and accepting or reject based on acceptance probability. The steps are: starting configuration of spins in the 1D lattice (spin up,down), randmoly change the spin of one lattice site, calculate the gap of energy between the old and new state, if the move is accepted (with probability exp(-ΔE/T) update the configuratio, otherwise keep the corrent state and try the move again.
# ## The Gibbs Sampling Algorithm: Start with initial configuration, for each lattice site sample a new spin value from the conditional distributiongiven the current states, the conditional distribution of the spins depends of the nearest neighboring spins and of the temperature, then update the configuration with the new sampled spins
# ## The main difference: Metropolis just flip randomly a spin, Gibbs depends on conditional distribution of each spin given all other spins in the lattice; The accept/reject ratio for Metropolis is around 50%, for Gibbs it is fixed to 1.

# %% [markdown]
# ## The values are at T=2.0

# %% [markdown]
# ## The block averages fluctuate much less then the individual estimates

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd

plt.rcParams.update({'font.size': 20})
M=100000            # Total number of throws
N=100          # Number of blocks
L=int(M/N)
x1 = np.arange(N)
x1*=L # Number of throws = block * (Number of throws in each block)

# %%
dataUGibbs = pd.read_csv('../Esercizio6/Gibbs/output.ene.0', sep='\s+', header=None, names=['uint', 'globuni','erru'])
dataUMetro = pd.read_csv('../Esercizio6/Metropolis/output.ene.0', sep='\s+', header=None, names=['uint', 'globuni','erru'])

# %%
plt.rcParams.update({'font.size': 20})
plt.errorbar(x1,dataUGibbs["uint"],yerr=dataUGibbs["erru"], label="Gibbs")
plt.errorbar(x1,dataUMetro["uint"],yerr=dataUMetro["erru"], label="Metropolis")
plt.rcParams["figure.figsize"]=(10,5)
plt.title('Ising 1D, internal energy')
plt.legend()
plt.xlabel('#throws')
plt.ylabel('U/N')
plt.grid(True)
plt.show()

# %% [markdown]
# ## The simulation for U/N with Gibbs and Metropolis are statisticly compatible

# %%
dataCGibbs = pd.read_csv('../Esercizio6/Gibbs/output.heat.0', sep='\s+', header=None, names=['uint', 'globuni','erru'])
dataCMetro = pd.read_csv('../Esercizio6/Metropolis/output.heat.0', sep='\s+', header=None, names=['uint', 'globuni','erru'])

# %%
plt.rcParams.update({'font.size': 25})
plt.errorbar(x1,dataCGibbs["uint"],yerr=dataCGibbs["erru"], label="Gibbs")
plt.errorbar(x1,dataCMetro["uint"],yerr=dataCMetro["erru"], label="Metropolis")
plt.rcParams["figure.figsize"]=(10,5)
plt.title('Ising 1D, heat')
plt.legend()
plt.xlabel('#throws')
plt.ylabel('C')
plt.grid(True)
plt.show()

# %% [markdown]
# ## The simulation for C with Gibbs and Metropolis are statisticly compatible

# %%
dataMGibbs = pd.read_csv('../Esercizio6/Gibbs/output.mag.0', sep='\s+', header=None, names=['uint', 'globuni','erru'])
dataMMetro = pd.read_csv('../Esercizio6/Metropolis/output.mag.0', sep='\s+', header=None, names=[ 'uint', 'globuni','erru'])

# %%
plt.rcParams.update({'font.size': 25})
plt.errorbar(x1,dataMGibbs["uint"],yerr=dataMGibbs["erru"], label="Gibbs")
plt.errorbar(x1,dataMMetro["uint"],yerr=dataMMetro["erru"], label="Metropolis")
plt.rcParams["figure.figsize"]=(10,5)
plt.title('Ising 1D, magnetization M with h = 0.02')
plt.legend()
plt.xlabel('#throws')
plt.ylabel('$M$')
plt.grid(True)
plt.show()

# %% [markdown]
# ## The simulation for M with Gibbs and Metropolis are statisticly compatible

# %%
dataChiGibbs = pd.read_csv('../Esercizio6/Gibbs/output.chi.0', sep='\s+', header=None, names=['uint', 'globuni','erru'])
dataChiMetro = pd.read_csv('../Esercizio6/Metropolis/output.chi.0', sep='\s+', header=None, names=['uint', 'globuni','erru'])

# %%
plt.rcParams.update({'font.size': 25})
plt.errorbar(x1,dataChiGibbs["uint"],yerr=dataChiGibbs["erru"], label="Gibbs")
plt.errorbar(x1,dataChiMetro["uint"],yerr=dataChiMetro["erru"], label="Metropolis")
plt.rcParams["figure.figsize"]=(10,5)
plt.title('Ising 1D, $\chi$')
plt.xlabel('#throws')
plt.ylabel('$\chi$')
plt.grid(True)
plt.show()

# %% [markdown]
# ## The simulation for $\chi$ with Gibbs and Metropolis are statisticly compatible

# %% [markdown]
# ## Comparing the Theorical values with Gibbs and Metropolis Simulation with many temperatures between [0.5,2]

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

points=100
T = np.linspace(0.2,3.0,num=points)
beta = 1/T
J = 1.0
Ns = 50
th = np.tanh(J/T)
thN= th**Ns
ch = 1/th
e = -J*( th + ch*thN )/( 1 + thN )

# %%
dataTotGibbs = pd.read_csv('../Esercizio6/output.eneGibbs.0', sep='\s+', header=None, names=['uint', 'globuni','erru'])
dataTotMC=pd.read_csv('../Esercizio6/output.eneMC.0', sep='\s+', header=None, names=['uint', 'globuni','erru'])

# %%
x2 = np.arange(0.5,2.1,0.1)
plt.plot(x2, dataTotGibbs['uint'], label="Gibbs")
plt.plot(x2, dataTotMC['uint'], label="Metropolis")
plt.plot(T, e, label="Teory")
plt.rcParams["figure.figsize"]=(10,5)
plt.title('Ising 1D, internal energy')
plt.legend()
plt.xlabel('T')
plt.ylabel('U/N')
plt.show()

# %%
dataTotGibbs1 = pd.read_csv('../Esercizio6/output.heatGibbs.0', sep='\s+', header=None, names=['uint', 'globuni','erru'])
dataTotMC1=pd.read_csv('../Esercizio6/output.heatMC.0', sep='\s+', header=None, names=['uint', 'globuni','erru'])

# %%
heat=((beta*J)**2)*(((1+thN+(Ns-1)*(th**2)+(Ns-1)*(ch**2)*thN)/(1+thN))-Ns*((th+ch*thN)/(1+thN))**2)

x2 = np.arange(0.5,2.1,0.1)
plt.plot(x2, dataTotGibbs1['uint'], label="Gibbs")
plt.plot(x2, dataTotMC1['uint'], label="Metropolis")
plt.plot(T, heat, label="Teory")
plt.rcParams["figure.figsize"]=(10,5)
plt.title('Ising 1D, heat')
plt.legend()
plt.xlabel('T')
plt.ylabel('C')
plt.show()

# %%
dataTotGibbs2 = pd.read_csv('../Esercizio6/output.magGibbs.0', sep='\s+', header=None, names=['uint', 'globuni','erru'])
dataTotMC2=pd.read_csv('../Esercizio6/output.magMC.0', sep='\s+', header=None, names=['uint', 'globuni','erru'])

# %%
h=0.02 #external field
b = 1/T

l1 = np.exp(b*J)*np.cosh(b*h)+np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
l2 = np.exp(b*J)*np.cosh(b*h)-np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
Z = l1**Ns + l2**Ns
M = (np.exp(b*J)*np.sinh(b*h)*((l1**(Ns-1))*(1+np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))) 
        + (l2**(Ns-1))*(1-np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J)))))/(Z)

x2 = np.arange(0.5,2.1,0.1)
plt.plot(x2, dataTotGibbs2['uint'], label="Gibbs")
plt.plot(x2, dataTotMC2['uint'], label="Metropolis")
plt.plot(T, M, label="Teory")
plt.rcParams["figure.figsize"]=(10,5)
plt.title('Ising 1D, magnetization M with h = 0.02')
plt.legend()
plt.xlabel('T')
plt.ylabel('$M$')
plt.show()

# %%
dataTotGibbs3 = pd.read_csv('../Esercizio6/output.chiGibbs.0', sep='\s+', header=None, names=['uint', 'globuni','erru'])
dataTotMC3=pd.read_csv('../Esercizio6/output.chiMC.0', sep='\s+', header=None, names=['uint', 'globuni','erru'])

# %%
X = beta*np.exp(2*beta*J)*(1-thN)/(1+thN)

x2 = np.arange(0.5,2.1,0.1)
plt.plot(x2, dataTotGibbs3['uint'], label="Gibbs")
plt.plot(x2, dataTotMC3['uint'], label="Metropolis")
plt.plot(T, X, label="Teory")
plt.rcParams["figure.figsize"]=(10,5)
plt.title('Ising 1D, $\chi$')
plt.legend()
plt.xlabel('T')
plt.ylabel('$\chi$')
plt.show()

# %% [markdown]
# ## For every quantities; U/N, C, M, $\chi$: The simulation with Metropolis and Gibbs sampling are compatible in every temperature between [0.5,2] with theoretical values.

# %% [markdown]
# In Statistical Mechanics the one-dimensional (1D) Ising Model is exactly resoluble. The Hamiltonian for a system of N spins with nearest neighbors interaction is given by (in the following I will assume units such that $\mu_B=1$ and $k_B=1$):
#
# $$
# H =
# -J\sum_{i=1}^N s_i s_{i+1}
# -\frac{h}{2}\sum_{i=1}^N (s_i + s_{i+1})
# $$
#
# where $\{ s_i \}_{i=1,N}$ are spin variables taking values in $\{-1;1\}$, $J>0$ (ferromagnetic model),and with the assumption $s_{N+1} = s_{1}$.
#
# The partition function for $N$ spins, $Z$, can be exactly computed and it turns out to be:
#
# $$
# Z=\sum_{\{ s_i \}} \exp \left( -\beta H\right) = \lambda_1^N + \lambda_2^N
# $$
#
# where
# $\lambda_{1,2} =
# e^{\beta J}
# \cosh (\beta h) \pm \left[ e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J) \right]^{1/2}$,
# and where $\beta=\frac{1}{k_b T} = \frac{1}{T}$.
# Once the partition function has been computed, the Helmholtz free energy is readly obtained as $A = -k_B T \ln Z$. All the thermodynamic quantities of interest can be deduced from $A$ or, equivalently, from $Z$:
#
# - the **Internal Energy** per spin (with $h=0$):
#
# $$
# \frac{U(N,T)}{N} = \frac{\langle H \rangle}{N}
# = \frac{1}{N} \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}
# = -\frac{1}{N}\frac{\partial \ln Z}{\partial \beta}
# \underset{h=0}= -J \tanh (\beta J) \Biggl( \frac{1 + \tanh^{N-2} (\beta J)}{1+\tanh^N (\beta J)} \Biggl)
# $$

# %% [markdown]
# - the **Heat Capacity** (with $h=0$):
#
# $$
# C(N,T) = \frac{\partial U(N,T)}{\partial T}
# = \frac{\partial \beta}{\partial T}\frac{\partial U}{\partial \beta}
# = -k_B\beta^2 \frac{\partial}{\partial \beta} \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z} \right] = \\
# = -k_B\beta^2 \left[ -\sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} + \sum_{\{ s_i \}} H \exp \left( -\beta H\right)\frac{\partial Z^{-1}}{\partial \beta} \right] = \\
# = k_B\beta^2 \left\{ \sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} + \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}\right]\frac{1}{Z}\frac{\partial Z}{\partial \beta} \right\} =\\
# = k_B\beta^2 \left\{ \sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} - \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}\right]^2 \right\} =
# k_B\beta^2 \left(\langle H^2 \rangle -\langle H \rangle^2 \right)
# $$
#
# $$
# \frac{C(N,T)}{N} = \frac{1}{N}\frac{\partial U(N,T)}{\partial T} =\\
# \underset{h=0}=
# k_B (\beta J)^2 \left\{ 1+\tanh^N (\beta J)+(N-1)\tanh^2 (\beta J)+(N-1)\frac{\tanh^{N-2} (\beta J)}{1+\tanh^N (\beta J)}
# - N \left[ \frac{\tanh (\beta J) + \tanh^{N-1} (\beta J)}{1+\tanh^N (\beta J)} \right]^2 \right\}
# $$

# %% [markdown]
# - the **Heat Capacity** (with $h=0$):
#
# $$
# C(N,T) = \frac{\partial U(N,T)}{\partial T}
# = \frac{\partial \beta}{\partial T}\frac{\partial U}{\partial \beta}
# = -k_B\beta^2 \frac{\partial}{\partial \beta} \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z} \right] = \\
# = -k_B\beta^2 \left[ -\sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} + \sum_{\{ s_i \}} H \exp \left( -\beta H\right)\frac{\partial Z^{-1}}{\partial \beta} \right] = \\
# = k_B\beta^2 \left\{ \sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} + \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}\right]\frac{1}{Z}\frac{\partial Z}{\partial \beta} \right\} =\\
# = k_B\beta^2 \left\{ \sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} - \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}\right]^2 \right\} =
# k_B\beta^2 \left(\langle H^2 \rangle -\langle H \rangle^2 \right)
# $$
#
# $$
# \frac{C(N,T)}{N} = \frac{1}{N}\frac{\partial U(N,T)}{\partial T} =\\
# \underset{h=0}=
# k_B (\beta J)^2 \left\{ 1+\tanh^N (\beta J)+(N-1)\tanh^2 (\beta J)+(N-1)\frac{\tanh^{N-2} (\beta J)}{1+\tanh^N (\beta J)}
# - N \left[ \frac{\tanh (\beta J) + \tanh^{N-1} (\beta J)}{1+\tanh^N (\beta J)} \right]^2 \right\}
# $$

# %% [markdown]
# - The **magnetization** (with $h \not= 0$):
#
# Note that with $h=0$ the magnetization $M(N,T,h=0)=\langle \sum_{i=1,N}s_i \rangle =0$ because in 1D we cannot have a (ferromagnetic) phase transition in absence of an external magnetic field.
#
# $$
# M(N,T,h) = -\frac{\partial A}{\partial h} = k_B T \frac{\partial \ln Z}{\partial h} =
# \frac{1}{\beta} \frac{1}{Z}\frac{\partial}{\partial h}\sum_{\{ s_i \}} \exp \left( -\beta H\right) = \sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z} = \left\langle \sum_{i=1,N}s_i \right\rangle
# $$
#
# The exact formula from $M(N,T,h) = k_B T \dfrac{\partial \ln Z}{\partial h}$ is:
# $$
# \frac{M(N,T,h)}{N}=\frac{e^{\beta J}\; \sinh(\beta h)}{Z} \; \Bigl[\lambda_1^{N-1}\cdot \Bigl(1+\frac{e^{\beta J}\; \cosh(\beta h)}{\sqrt{e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J)}}\Bigr) + \lambda_2^{N-1}\cdot \Bigl(1-\frac{e^{\beta J}\; \cosh(\beta h)}{\sqrt{e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J)}}\Bigr)\Bigr]
# $$

# %% [markdown]
# - The **magnetic susceptibility** (with $h=0$):
#
# $$
# \chi(N,T) = \frac{\partial M}{\partial h} =
# \frac{\partial}{\partial h}\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z} =\\
# = \beta\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right]^2 \frac{\exp \left( -\beta H\right)}{Z}
# -\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z}
# \frac{1}{Z}\frac{\partial Z}{\partial h} =
# \beta \left[ \left\langle \left( \sum_{i=1,N}s_i \right)^2 \right\rangle - \left\langle \sum_{i=1,N}s_i \right\rangle^2 \right] = \\
# \underset{h=0}= \beta \left[ \left\langle \left( \sum_{i=1,N}s_i \right)^2 \right\rangle \right] = \beta e^{2\beta J} \Biggl( \frac{1-\tanh^N (\beta J)}{1+\tanh^N (\beta J)} \Biggl)
# $$

# %% [markdown]
# Complete the C++ code to simulate 1D Ising model with
# - the Metropolis sampling algorithm and
# - the Gibbs sampling algorithm
#
# to sample the Boltzmann's weight $p(\{ s_i \}) = \exp(-\beta H)/Z$,
# adding also the possibility to restart from a previous spin configuration.
#
# The code already computes the internal energy: $U(N,T) = \langle H \rangle$. Add the calculation of $C(N,T)$, $\chi(N,T)$, $M(N,T,h)$ and compute:
# 1. $U(N,T) = \langle H \rangle_{h=0}$
# 2. $C(N,T) = k_B \beta^2 (\langle H^2 \rangle_{h=0}-\langle H \rangle_{h=0}^2)$
# 3. $\chi(N,T) = \beta \langle (\sum_{i=1,N}s_i)^2 \rangle_{h=0}$
# 4. $M(N,T,h=0.02)= \langle \sum_{i=1,N}s_i \rangle_{h=0.02}$
#
# as a function of $T$ in the range $\left[0.5;2.0\right]$ for a system of $N=50$ spins with $J=1$.
#
# As usual, use data blocking and give an estimate of the statistical uncertainties.
#
# - <span style="color:red">Show pictures of your estimations of $U(N,T)$, $C(N,T)$, $\chi(N,T)$, $M(N,T,h=0.02)$ and their uncertainties</span> obtained with a large number of *MC steps* (e.g. $M\ge 10^5$) compared with the exact curves. In the same picture show your results obtained with both sampling methods, Metropolis and Gibbs.
#
# A Monte Carlo step will consist in trying to flip one time all the spins of the system. Do not forget to equilibrate your simulations and to use blocking average with blocks large enough.
